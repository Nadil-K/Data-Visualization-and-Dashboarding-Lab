# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Kickstarter.csv', encoding='latin-1')
df = df.sort_values(df.columns[7])
df = df.drop(df.index[:5])
df = df.drop(df.columns[7], axis=1)
colNames = ['Name', 'Category', 'Deadline', 'Goal', 'Pledged', 'Status', 'Backers']
df.columns = colNames
df['Deadline'] = df.Deadline.str.split(' ').str[0]
df['Deadline'] = pd.to_datetime(df['Deadline'],dayfirst=True, format='mixed')
df = df.drop(15260)
# Reset the index of the DataFrame
df = df.reset_index(drop=True)
df = df[df['Status'] != 'undefined']
df.dropna(inplace=True)
df['Pledged'] = df.apply(lambda row: row['Pledged'] if row['Backers'] != 0 else 0, axis=1)
df['Backers'] = df.apply(lambda row: row['Backers'] if row['Pledged'] != 0 else 0, axis=1)

data_types = {'Name': str,
              'Category': str,
              'Deadline': 'datetime64[ns]',
              'Goal': float,
              'Pledged': float,
              'Status': str,
              'Backers': int}

df = df.astype(data_types)



df['percentage'] = df['Pledged'] /df['Goal']*100
df['percentage'] = df['percentage'].apply(lambda x: float("{:.2f}".format(x)))


df['each_backer_pledge'] = (df['Pledged'] / df['Backers']).round(2).astype(float)
df['each_backer_pledge'].fillna(0, inplace=True)

df_mod.sort_values('each_backer_pledge')

# df.to_csv('cleaned_data.csv', index=False)

df
# Out:
#                                                     Name  Category   Deadline  \
# 0                                             Safer Home  Hardware 2015-07-03
# 1      Gizbee Unlimited Removable Storage for Your T...   Gadgets 2016-03-25
# 2      Diposta - liberating people from their postal ...       Web 2016-08-23
# 3                      Best Spray Bottle Ever - SureShot   Gadgets 2015-03-07
# 4      Fishtacular - The Ultimate Fishing Tool (Cance...      Apps 2015-05-25
# ...                                                  ...       ...        ...
# 15989  Safeskoolz: Safety & Emergency Communication F...      Apps 2014-08-09
# 15990  The Beer Machine that keeps track of who's dri...  Hardware 2016-12-07
# 15991  CopCritic App: Helping Police & Public Communi...      Apps 2016-11-04
# 15992                    Geeftz for Christmas (Canceled)      Apps 2015-01-03
# 15993            "The Original BluGuitar Speaker System"     Sound 2014-07-02
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15991 entries, 0 to 15993
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                15991 non-null  object
#  1   Category            15991 non-null  object
#  2   Deadline            15991 non-null  datetime64[ns]
#  3   Goal                15991 non-null  float64
#  4   Pledged             15991 non-null  float64
#  5   Status              15991 non-null  object
#  6   Backers             15991 non-null  int32
#  7   percentage          15991 non-null  float64
#  8   each_backer_pledge  13294 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int32(1), object(3)
# memory usage: 1.2+ MB
#                             Deadline          Goal       Pledged  \
# count                          15991  1.599100e+04  1.599100e+04
# mean   2015-04-03 01:55:37.502345216  1.197891e+05  2.036791e+04
# ...

# %%
df['Status'].value_counts()
# Out:
# Status
# failed        10063
# successful     3101
# canceled       2244
# live            390
# suspended       193
# Name: count, dtype: int64

# %%
df_mod = df[df['Status'].isin(['successful'])].sort_values('Deadline')
df_mod = df_mod.drop([df.each_backer_pledge == 'inf']).reset_index(drop=True)
df_mod.sort_values('each_backer_pledge')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[205], line 2
#       1 df_mod = df[df['Status'].isin(['successful'])].sort_values('Deadline')
# ----> 2 df_mod = df_mod.drop([df.each_backer_pledge == 'inf']).reset_index(drop=True)
#       3 df_mod.sort_values('each_backer_pledge')
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...

# %%
# df.to_csv('output.csv', index=False)
df.sort_values('each_backer_pledge')
# Out:
#                                                     Name     Category  \
# 0                                             Safer Home     Hardware
# 13939  Sotro - The Social Introducer - German Transla...         Apps
# 5148   High Quality Websites, Logos & Stationery For ...          Web
# 5149   Tripz - a group holiday planning platform (Can...         Apps
# 5152        Draze Search - Family Friendly Search Engine          Web
# ...                                                  ...          ...
# 1557   Affordable DLP 3D Printer - Amazing 2K Resolution  3D Printing
# 6312     Evivar, små batterier som varer - til elsykkel!     Hardware
# 5772         Recycle platinum from automotive catalysts.   Technology
# 6043             Rolling Walker with Concurrent Feedback   Technology
# 856    SCiO: Your Sixth Sense. A Pocket Molecular Sen...     Hardware
#
#         Deadline       Goal     Pledged      Status  Backers  percentage  \
# ...
